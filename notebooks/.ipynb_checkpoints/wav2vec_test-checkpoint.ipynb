# %% [markdown]
# # wav2vec_test
# - force align each annotation/wav snippet
# - save results in json file

# %%
import os
import json
import torch
import IPython
import torchaudio
import matplotlib.pyplot as plt
from dataclasses import dataclass


print(torch.__version__)
print(torchaudio.__version__)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

torch.random.manual_seed(0)
# Out:
# 2.1.2+cpu
# 2.1.2+cpu
# cpu

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model = bundle.get_model().to(device)
labels = bundle.get_labels()

print(labels)
# Out:
# ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %%
folder_path = 'C:\\Users\\barth\\gits\\pytorch_wav2vec\\test_data\\'
inputPath = folder_path + "input\\"
mediaPath = folder_path + "media_snippets\\"

def read_json_file(filename):
    try:
        with open(filename, 'r') as json_file:
            data = json.load(json_file)
            return data
    except Exception as e:
        print(f"Error reading JSON file: {e}")
        return None

def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    trellis = torch.zeros((num_frame, num_tokens))
    trellis[1:, 0] = torch.cumsum(emission[1:, blank_id], 0)
    trellis[0, 1:] = -float("inf")
    trellis[-num_tokens + 1 :, 0] = float("inf")

    for t in range(num_frame - 1):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens[1:]],
        )
    return trellis

def plot():
    fig, ax = plt.subplots()
    img = ax.imshow(trellis.T, origin="lower")
    ax.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
    ax.annotate("+ Inf", (trellis.size(0) - trellis.size(1) / 5, trellis.size(1) / 3))
    fig.colorbar(img, ax=ax, shrink=0.6, location="bottom")
    fig.tight_layout()

@dataclass
class Point:
    token_index: int
    time_index: int
    score: float

def backtrack(trellis, emission, tokens, blank_id=0):
    t, j = trellis.size(0) - 1, trellis.size(1) - 1

    path = [Point(j, t, emission[t, blank_id].exp().item())]
    while j > 0:
        # Should not happen but just in case
        assert t > 0

        # 1. Figure out if the current position was stay or change
        # Frame-wise score of stay vs change
        p_stay = emission[t - 1, blank_id]
        p_change = emission[t - 1, tokens[j]]

        # Context-aware score for stay vs change
        stayed = trellis[t - 1, j] + p_stay
        changed = trellis[t - 1, j - 1] + p_change

        # Update position
        t -= 1
        if changed > stayed:
            j -= 1

        # Store the path with frame-wise probability.
        prob = (p_change if changed > stayed else p_stay).exp().item()
        path.append(Point(j, t, prob))

    # Now j == 0, which means, it reached the SoS.
    # Fill up the rest for the sake of visualization
    while t > 0:
        prob = emission[t - 1, blank_id].exp().item()
        path.append(Point(j, t - 1, prob))
        t -= 1

    return path[::-1]

# Merge the labels
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments

# Merge words
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words

def segment_info(i):
    ratio = waveform.size(1) / trellis.size(0)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    #print(f"{word.label} ({word.score:.2f}): {x0 / 44100:.3f} - {x1 / 44100:.3f} sec")
    return ([f"{word.label}", format(x0 / 44100,'.3f') , format(x1 / 44100, '.3f')])
    

for filename in os.listdir(mediaPath):
    counter  = 0
    
    if filename.endswith('.json'):
        jsonFile = mediaPath + filename
        json_data = read_json_file(jsonFile)
        for k, v in json_data.items():
            
            text_clean = v["text"].upper().replace(' ', '|')
            #print (text_clean)
            transcript = text_clean
            dictionary = {c: i for i, c in enumerate(labels)}
            
            tokens = [dictionary[c] for c in transcript]
            #print(list(zip(transcript, tokens)))

            SPEECH_FILE = "C:/Users/barth/gits/pytorch_wav2vec/test_data/media_snippets/" + filename[:-4] + "\\" + k.replace(" ", "_") + ".wav" #Cathy_Samun_Wiliang_a1.wav"
            
            #bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
            
            #model = bundle.get_model().to(device)
            #labels = bundle.get_labels()
            
            
            with torch.inference_mode():
                waveform, _ = torchaudio.load(SPEECH_FILE)
                emissions, _ = model(waveform.to(device))
                emissions = torch.log_softmax(emissions, dim=-1)
            
            emission = emissions[0].cpu().detach()
            metadata = torchaudio.info(SPEECH_FILE)
            print(metadata)
            
            trellis = get_trellis(emission, tokens)
           
            #plot()
            
            path = backtrack(trellis, emission, tokens)

            segments = merge_repeats(path)
            
                
            word_segments = merge_words(segments)
            word_list = []
            for x in range(0, len(word_segments)):
                wordInfo = segment_info(x)
                wordInfo[1] = int(float(wordInfo[1]) * 1000) + v['timeStamp1']
                wordInfo[2] = int(float(wordInfo[2]) * 1000) + v['timeStamp1']
                print(wordInfo)
                
                word_list.append(wordInfo)


            print (word_list)
            print(v)
            v["tier_new"] = v["tiername"] + "_words"
            v["words"] = word_list
                
            
            
            #print(transcript)
            #display_segment(-1)
            #IPython.display.Audio(SPEECH_FILE, rate=44100)

        print (json_data)
        with open(jsonFile, 'w') as json_file:
            json.dump(json_data, json_file, indent=2)

print (" +++ DONE +++" )
# Out:
# AudioMetaData(sample_rate=44100, num_frames=121275, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['YANGAU', 4730, 5407]
# ['CATHY', 6294, 6687]
# ['SAMUN', 6745, 7116]
# ['AI', 7276, 7480]
# [['YANGAU', 4730, 5407], ['CATHY', 6294, 6687], ['SAMUN', 6745, 7116], ['AI', 7276, 7480]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 4730, 'timeStamp2': 7480, 'text': 'Yangau Cathy Samun ai'}
# AudioMetaData(sample_rate=44100, num_frames=84672, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 8860, 9216]
# ['MAM', 9296, 9427]
# ['YANGAN', 9507, 9653]
# ['DAIDAI', 9682, 10067]
# ['AI', 10075, 10780]
# [['NGAHAU', 8860, 9216], ['MAM', 9296, 9427], ['YANGAN', 9507, 9653], ['DAIDAI', 9682, 10067], ['AI', 10075, 10780]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8860, 'timeStamp2': 10780, 'text': 'Ngahau mam yangan Daidai ai'}
# AudioMetaData(sample_rate=44100, num_frames=133711, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 11821, 12337]
# ['TAMAT', 12439, 12672]
# ['YANGAN', 12759, 13043]
# ['WILIANG', 13144, 13493]
# ['YASUNG', 14031, 14584]
# ['AI', 14591, 14853]
# [['NGAU', 11821, 12337], ['TAMAT', 12439, 12672], ['YANGAN', 12759, 13043], ['WILIANG', 13144, 13493], ['YASUNG', 14031, 14584], ['AI', 14591, 14853]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11821, 'timeStamp2': 14853, 'text': 'Ngau tamat yangan Wiliang Yasung ai'}
# AudioMetaData(sample_rate=44100, num_frames=151131, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 15733, 16394]
# ['NEN', 16553, 16720]
# ['MAM', 17802, 17911]
# ['MATUGAR', 17955, 18231]
# ['TAMATPAINIM', 18281, 19160]
# [['NGAHAU', 15733, 16394], ['NEN', 16553, 16720], ['MAM', 17802, 17911], ['MATUGAR', 17955, 18231], ['TAMATPAINIM', 18281, 19160]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15733, 'timeStamp2': 19160, 'text': 'Ngahau nen mam Matugar tamatpainim'}
# AudioMetaData(sample_rate=44100, num_frames=92213, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 20618, 21026]
# ['MATUGAR', 21092, 21463]
# ['TAMAT', 21514, 21776]
# ['NGANGALENGE', 21849, 22709]
# [['NGAU', 20618, 21026], ['MATUGAR', 21092, 21463], ['TAMAT', 21514, 21776], ['NGANGALENGE', 21849, 22709]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 20618, 'timeStamp2': 22709, 'text': 'Ngau Matugar tamat ngangalenge'}
# AudioMetaData(sample_rate=44100, num_frames=86612, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['HAMAM', 24013, 24755]
# ['AIPAIN', 24893, 25184]
# ['AIM', 25279, 25359]
# ['TOL', 25482, 25977]
# [['HAMAM', 24013, 24755], ['AIPAIN', 24893, 25184], ['AIM', 25279, 25359], ['TOL', 25482, 25977]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 24013, 'timeStamp2': 25977, 'text': 'Hamam aipain aim tol'}
# AudioMetaData(sample_rate=44100, num_frames=286474, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MUGANEN', 27757, 28266]
# ['MAINANGAN', 28302, 29029]
# ['GUMOS', 29668, 30322]
# ['AI', 30366, 30416]
# ['SALOME', 30518, 31158]
# ['AI', 31267, 31296]
# ['DO', 31347, 31361]
# ['AIM', 31492, 31601]
# ['TAHAIK', 31775, 32088]
# ['YASUNG', 33403, 33839]
# ['AI', 33991, 34253]
# [['MUGANEN', 27757, 28266], ['MAINANGAN', 28302, 29029], ['GUMOS', 29668, 30322], ['AI', 30366, 30416], ['SALOME', 30518, 31158], ['AI', 31267, 31296], ['DO', 31347, 31361], ['AIM', 31492, 31601], ['TAHAIK', 31775, 32088], ['YASUNG', 33403, 33839], ['AI', 33991, 34253]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 27757, 'timeStamp2': 34253, 'text': 'Muganen mainangan Gumos ai Salome ai do aim tahaik  Yasung ai'}
# AudioMetaData(sample_rate=44100, num_frames=127272, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['TIBUN', 34721, 35230]
# ['HAN', 35484, 35593]
# ['YAYAMAN', 35848, 36386]
# ['NGAMNAGENGE', 36458, 37076]
# ['TAMAT', 37113, 37607]
# [['TIBUN', 34721, 35230], ['HAN', 35484, 35593], ['YAYAMAN', 35848, 36386], ['NGAMNAGENGE', 36458, 37076], ['TAMAT', 37113, 37607]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a9', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 34721, 'timeStamp2': 37607, 'text': 'Tibun han yayaman ngamnagenge tamat'}
# AudioMetaData(sample_rate=44100, num_frames=80791, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 38705, 39221]
# ['NGAU', 39265, 39432]
# ['SULELO', 39476, 40413]
# ['NGAUWE', 40421, 40537]
# [['DO', 38705, 39221], ['NGAU', 39265, 39432], ['SULELO', 39476, 40413], ['NGAUWE', 40421, 40537]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a10', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 38705, 'timeStamp2': 40537, 'text': 'Do ngau sulelo ngauwe'}
# AudioMetaData(sample_rate=44100, num_frames=123083, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 40926, 41747]
# ['SULE', 41827, 42140]
# ['TOMANTE', 42191, 42685]
# ['TI', 42758, 42874]
# ['TIALE', 42954, 43717]
# [['NGAHAU', 40926, 41747], ['SULE', 41827, 42140], ['TOMANTE', 42191, 42685], ['TI', 42758, 42874], ['TIALE', 42954, 43717]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a11', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 40926, 'timeStamp2': 43717, 'text': 'Ngahau sule tomante ti tiale'}
# AudioMetaData(sample_rate=44100, num_frames=46570, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MATENGALO', 44815, 45871]
# [['MATENGALO', 44815, 45871]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a12', 'timeSlotRef1': 'ts21', 'timeSlotRef2': 'ts22', 'timeStamp1': 44815, 'timeStamp2': 45871, 'text': 'Matengalo'}
# AudioMetaData(sample_rate=44100, num_frames=175650, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MATENG', 46642, 47332]
# ['FUNAUWE', 47412, 47899]
# ['NGAM', 47928, 48168]
# ['SULE', 48873, 49171]
# ['HAN', 49331, 49469]
# ['TOMANTE', 49542, 49869]
# ['TI', 49934, 50051]
# ['TIE', 50145, 50625]
# [['MATENG', 46642, 47332], ['FUNAUWE', 47412, 47899], ['NGAM', 47928, 48168], ['SULE', 48873, 49171], ['HAN', 49331, 49469], ['TOMANTE', 49542, 49869], ['TI', 49934, 50051], ['TIE', 50145, 50625]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a13', 'timeSlotRef1': 'ts23', 'timeSlotRef2': 'ts24', 'timeStamp1': 46642, 'timeStamp2': 50625, 'text': 'Mateng funauwe ngam sule han tomante ti tie'}
# AudioMetaData(sample_rate=44100, num_frames=178120, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 52201, 52586]
# ['NEN', 52659, 53036]
# ['MAM', 53095, 53356]
# ['DIDA', 53545, 53676]
# ['NGAMMADONGE', 54431, 55405]
# ['YAUWE', 55535, 56239]
# [['DO', 52201, 52586], ['NEN', 52659, 53036], ['MAM', 53095, 53356], ['DIDA', 53545, 53676], ['NGAMMADONGE', 54431, 55405], ['YAUWE', 55535, 56239]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a14', 'timeSlotRef1': 'ts25', 'timeSlotRef2': 'ts26', 'timeStamp1': 52201, 'timeStamp2': 56240, 'text': 'Do nen mam dida ngammadonge yauwe'}
# AudioMetaData(sample_rate=44100, num_frames=119555, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NAL', 57160, 57712]
# ['NGAU', 57749, 57930]
# ['PAIN', 58090, 58228]
# ['DABOKE', 58279, 58795]
# ['TAMAT', 58839, 59093]
# ['NGANGALENGE', 59181, 59871]
# [['NAL', 57160, 57712], ['NGAU', 57749, 57930], ['PAIN', 58090, 58228], ['DABOKE', 58279, 58795], ['TAMAT', 58839, 59093], ['NGANGALENGE', 59181, 59871]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a15', 'timeSlotRef1': 'ts27', 'timeSlotRef2': 'ts28', 'timeStamp1': 57160, 'timeStamp2': 59871, 'text': 'Nal ngau pain daboke tamat ngangalenge'}
# AudioMetaData(sample_rate=44100, num_frames=160216, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['AIPAINIM', 60079, 60784]
# ['NGANAGEDINE', 60791, 61387]
# ['MALAL', 61430, 61794]
# ['MAINTE', 61874, 61983]
# ['NGAMADONGE', 62063, 62709]
# ['MATUGAR', 62753, 63153]
# ['MALAL', 63232, 63479]
# [['AIPAINIM', 60079, 60784], ['NGANAGEDINE', 60791, 61387], ['MALAL', 61430, 61794], ['MAINTE', 61874, 61983], ['NGAMADONGE', 62063, 62709], ['MATUGAR', 62753, 63153], ['MALAL', 63232, 63479]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a16', 'timeSlotRef1': 'ts29', 'timeSlotRef2': 'ts30', 'timeStamp1': 60079, 'timeStamp2': 63712, 'text': 'Aipainim nganagedine malal mainte ngamadonge Matugar malal '}
# AudioMetaData(sample_rate=44100, num_frames=176577, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 65418, 66166]
# ['NGAHAU', 67075, 67293]
# ['NERAURAU', 67387, 67801]
# ['NGAPASIMBAI', 67816, 68419]
# ['MAIN', 68470, 68601]
# ['MARIU', 68688, 68957]
# ['HAN', 69008, 69421]
# [['DO', 65418, 66166], ['NGAHAU', 67075, 67293], ['NERAURAU', 67387, 67801], ['NGAPASIMBAI', 67816, 68419], ['MAIN', 68470, 68601], ['MARIU', 68688, 68957], ['HAN', 69008, 69421]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a17', 'timeSlotRef1': 'ts31', 'timeSlotRef2': 'ts32', 'timeStamp1': 65418, 'timeStamp2': 69422, 'text': 'Do  ngahau neraurau ngapasimbai main mariu han'}
# AudioMetaData(sample_rate=44100, num_frames=100152, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 70869, 71291]
# ['TAMAT', 71357, 71590]
# ['IDA', 71706, 71954]
# ['NGAMADONG', 71990, 72288]
# ['NGAU', 72325, 72543]
# ['TAMAT', 72623, 73140]
# [['NGAHAU', 70869, 71291], ['TAMAT', 71357, 71590], ['IDA', 71706, 71954], ['NGAMADONG', 71990, 72288], ['NGAU', 72325, 72543], ['TAMAT', 72623, 73140]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a18', 'timeSlotRef1': 'ts33', 'timeSlotRef2': 'ts34', 'timeStamp1': 70869, 'timeStamp2': 73140, 'text': 'Ngahau tamat ida ngamadong  ngau tamat'}
# AudioMetaData(sample_rate=44100, num_frames=254457, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['SULELO', 74450, 75119]
# ['YAKAI', 75169, 75598]
# ['ILO', 75707, 75853]
# ['GREK', 75903, 76078]
# ['TI', 76085, 77328]
# ['IDA', 77778, 77931]
# ['TIDASE', 78004, 78621]
# ['MALALTE', 78774, 79428]
# ['MADONGE', 79471, 79777]
# ['NGALEUWE', 79886, 80220]
# [['SULELO', 74450, 75119], ['YAKAI', 75169, 75598], ['ILO', 75707, 75853], ['GREK', 75903, 76078], ['TI', 76085, 77328], ['IDA', 77778, 77931], ['TIDASE', 78004, 78621], ['MALALTE', 78774, 79428], ['MADONGE', 79471, 79777], ['NGALEUWE', 79886, 80220]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a19', 'timeSlotRef1': 'ts35', 'timeSlotRef2': 'ts36', 'timeStamp1': 74450, 'timeStamp2': 80220, 'text': 'Sulelo yakai ilo grek ti ida tidase malalte madonge ngaleuwe'}
# AudioMetaData(sample_rate=44100, num_frames=170005, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAMADONDO', 81473, 82468]
# ['NGAHAMAM', 82816, 83462]
# ['AIPAINIM', 83513, 84014]
# ['YAMATAIE', 84043, 84246]
# ['NGALE', 84254, 84391]
# ['MATAN', 84442, 84587]
# ['TI', 84747, 85328]
# [['NGAMADONDO', 81473, 82468], ['NGAHAMAM', 82816, 83462], ['AIPAINIM', 83513, 84014], ['YAMATAIE', 84043, 84246], ['NGALE', 84254, 84391], ['MATAN', 84442, 84587], ['TI', 84747, 85328]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a21', 'timeSlotRef1': 'ts37', 'timeSlotRef2': 'ts38', 'timeStamp1': 81473, 'timeStamp2': 85328, 'text': 'Ngamadondo ngahamam aipainim yamataie ngale matan ti'}
# AudioMetaData(sample_rate=44100, num_frames=345215, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 86828, 87242]
# ['MANIG', 87285, 87511]
# ['ILOMAM', 87590, 88092]
# ['GIRENGE', 88113, 88367]
# ['TAN', 88418, 88585]
# ['NGAMBIP', 88651, 89086]
# ['MARIU', 90125, 90364]
# ['NGAMPAIP', 90408, 90909]
# ['MATAN', 91076, 91374]
# ['NGAMNGALEP', 91410, 91737]
# ['NGAHAMAM', 91773, 92354]
# ['AIPAINIM', 92478, 92797]
# ['NGAMYAMATAIBA', 92855, 94656]
# [['DO', 86828, 87242], ['MANIG', 87285, 87511], ['ILOMAM', 87590, 88092], ['GIRENGE', 88113, 88367], ['TAN', 88418, 88585], ['NGAMBIP', 88651, 89086], ['MARIU', 90125, 90364], ['NGAMPAIP', 90408, 90909], ['MATAN', 91076, 91374], ['NGAMNGALEP', 91410, 91737], ['NGAHAMAM', 91773, 92354], ['AIPAINIM', 92478, 92797], ['NGAMYAMATAIBA', 92855, 94656]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a23', 'timeSlotRef1': 'ts39', 'timeSlotRef2': 'ts40', 'timeStamp1': 86828, 'timeStamp2': 94656, 'text': 'Do manig ilomam girenge tan ngambip mariu ngampaip matan ngamngalep ngahamam aipainim ngamyamataiba'}
# AudioMetaData(sample_rate=44100, num_frames=194172, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 96153, 96567]
# ['MARIU', 96618, 96858]
# ['NGAMPAINGE', 96901, 97628]
# ['BRAS', 97650, 97984]
# ['NUMAU', 98296, 98572]
# ['TAHAIK', 98623, 98863]
# ['ILONLO', 98972, 99393]
# ['AGINON', 99502, 99851]
# ['NAGENGE', 99909, 100556]
# [['DO', 96153, 96567], ['MARIU', 96618, 96858], ['NGAMPAINGE', 96901, 97628], ['BRAS', 97650, 97984], ['NUMAU', 98296, 98572], ['TAHAIK', 98623, 98863], ['ILONLO', 98972, 99393], ['AGINON', 99502, 99851], ['NAGENGE', 99909, 100556]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a25', 'timeSlotRef1': 'ts41', 'timeSlotRef2': 'ts42', 'timeStamp1': 96153, 'timeStamp2': 100556, 'text': 'Do mariu ngampainge bras numau tahaik ilonlo aginon nagenge'}
# AudioMetaData(sample_rate=44100, num_frames=290839, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['YAP', 100694, 101028]
# ['DISINGE', 101123, 101660]
# ['NGAMAM', 101740, 102154]
# ['MARIU', 102227, 102481]
# ['DIDADO', 102626, 103519]
# ['MAINHONA', 103577, 103970]
# ['NGAHAU', 104943, 105234]
# ['AIPAINIM', 105342, 105735]
# ['ADI', 105742, 105785]
# ['SULE', 105829, 105996]
# ['NGADADAGOKAI', 106069, 107289]
# [['YAP', 100694, 101028], ['DISINGE', 101123, 101660], ['NGAMAM', 101740, 102154], ['MARIU', 102227, 102481], ['DIDADO', 102626, 103519], ['MAINHONA', 103577, 103970], ['NGAHAU', 104943, 105234], ['AIPAINIM', 105342, 105735], ['ADI', 105742, 105785], ['SULE', 105829, 105996], ['NGADADAGOKAI', 106069, 107289]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a26', 'timeSlotRef1': 'ts43', 'timeSlotRef2': 'ts44', 'timeStamp1': 100694, 'timeStamp2': 107289, 'text': 'Yap disinge ngamam mariu didado mainhona  ngahau aipainim adi sule ngadadagokai'}
# AudioMetaData(sample_rate=44100, num_frames=172299, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['HADI', 107437, 107720]
# ['SULUNGAK', 107764, 108127]
# ['NAGEKANEN', 108621, 109129]
# ['HAN', 109202, 109565]
# ['NGADADAGOKAI', 109601, 111344]
# [['HADI', 107437, 107720], ['SULUNGAK', 107764, 108127], ['NAGEKANEN', 108621, 109129], ['HAN', 109202, 109565], ['NGADADAGOKAI', 109601, 111344]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a28', 'timeSlotRef1': 'ts45', 'timeSlotRef2': 'ts46', 'timeStamp1': 107437, 'timeStamp2': 111344, 'text': 'Hadi sulungak nagekanen han ngadadagokai'}
# AudioMetaData(sample_rate=44100, num_frames=172740, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAMAM', 111907, 112510]
# ['MADOK', 112539, 112909]
# ['KABAKAB', 112932, 113302]
# ['ADI', 113317, 113462]
# ['MILO', 113491, 113615]
# ['YANIKANEN', 113637, 114269]
# ['MAIN', 114560, 114661]
# ['MATAN', 114712, 114988]
# ['MAIN', 115054, 115177]
# ['HONA', 115279, 115824]
# [['NGAHAMAM', 111907, 112510], ['MADOK', 112539, 112909], ['KABAKAB', 112932, 113302], ['ADI', 113317, 113462], ['MILO', 113491, 113615], ['YANIKANEN', 113637, 114269], ['MAIN', 114560, 114661], ['MATAN', 114712, 114988], ['MAIN', 115054, 115177], ['HONA', 115279, 115824]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a30', 'timeSlotRef1': 'ts47', 'timeSlotRef2': 'ts48', 'timeStamp1': 111907, 'timeStamp2': 115824, 'text': 'Ngahamam madok kabakab adi milo yanikanen main matan  main hona'}
# AudioMetaData(sample_rate=44100, num_frames=264424, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['PATATAN', 116579, 117073]
# ['MALALTE', 117102, 117544]
# ['NAGEKANEN', 117573, 118082]
# ['MARIU', 118103, 118706]
# ['HAN', 118735, 118960]
# ['MATAN', 119025, 119316]
# ['HONAMI', 119352, 119824]
# ['NGAMBI', 121232, 121544]
# ['NGAMMALENGGOKAI', 121610, 122575]
# [['PATATAN', 116579, 117073], ['MALALTE', 117102, 117544], ['NAGEKANEN', 117573, 118082], ['MARIU', 118103, 118706], ['HAN', 118735, 118960], ['MATAN', 119025, 119316], ['HONAMI', 119352, 119824], ['NGAMBI', 121232, 121544], ['NGAMMALENGGOKAI', 121610, 122575]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a31', 'timeSlotRef1': 'ts49', 'timeSlotRef2': 'ts50', 'timeStamp1': 116579, 'timeStamp2': 122575, 'text': 'Patatan malalte nagekanen mariu han matan honami  ngambi ngammalenggokai'}
# AudioMetaData(sample_rate=44100, num_frames=300629, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 124050, 124464]
# ['GAMONI', 124594, 125037]
# ['NGAU', 125219, 125589]
# ['ABATE', 125604, 125959]
# ['WAP', 125996, 126134]
# ['NGAHAU', 126141, 127114]
# ['AB', 127607, 127673]
# ['MAINANGAN', 127789, 128275]
# ['MARIU', 128587, 128776]
# ['HAN', 128812, 128907]
# ['MATAN', 128987, 129248]
# ['HONAMI', 129313, 129705]
# ['MILO', 129756, 129952]
# ['NGAMANINGGO', 130039, 130867]
# [['DO', 124050, 124464], ['GAMONI', 124594, 125037], ['NGAU', 125219, 125589], ['ABATE', 125604, 125959], ['WAP', 125996, 126134], ['NGAHAU', 126141, 127114], ['AB', 127607, 127673], ['MAINANGAN', 127789, 128275], ['MARIU', 128587, 128776], ['HAN', 128812, 128907], ['MATAN', 128987, 129248], ['HONAMI', 129313, 129705], ['MILO', 129756, 129952], ['NGAMANINGGO', 130039, 130867]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a33', 'timeSlotRef1': 'ts51', 'timeSlotRef2': 'ts52', 'timeStamp1': 124050, 'timeStamp2': 130867, 'text': 'Do gamoni ngau abate wap ngahau ab mainangan mariu han matan honami milo ngamaninggo'}
# AudioMetaData(sample_rate=44100, num_frames=117306, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MARIU', 131085, 131666]
# ['HAN', 131688, 131826]
# ['MATAN', 131884, 132190]
# ['HONAMI', 132233, 132539]
# ['MILO', 132691, 132844]
# ['MILO', 132887, 133025]
# ['HUDUNGAN', 133047, 133745]
# [['MARIU', 131085, 131666], ['HAN', 131688, 131826], ['MATAN', 131884, 132190], ['HONAMI', 132233, 132539], ['MILO', 132691, 132844], ['MILO', 132887, 133025], ['HUDUNGAN', 133047, 133745]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a35', 'timeSlotRef1': 'ts53', 'timeSlotRef2': 'ts54', 'timeStamp1': 131085, 'timeStamp2': 133745, 'text': 'Mariu han matan honami milo milo hudungan'}
# AudioMetaData(sample_rate=44100, num_frames=377805, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['EBLONG', 135643, 136217]
# ['PATATAN', 137872, 138257]
# ['DABOK', 138300, 138518]
# ['MALALTE', 138620, 139636]
# ['MATENG', 139723, 140355]
# ['HAN', 140427, 140645]
# ['O', 142090, 142177]
# ['MILO', 143121, 143368]
# ['YANIK', 143397, 143665]
# ['HAN', 143774, 144210]
# [['EBLONG', 135643, 136217], ['PATATAN', 137872, 138257], ['DABOK', 138300, 138518], ['MALALTE', 138620, 139636], ['MATENG', 139723, 140355], ['HAN', 140427, 140645], ['O', 142090, 142177], ['MILO', 143121, 143368], ['YANIK', 143397, 143665], ['HAN', 143774, 144210]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a36', 'timeSlotRef1': 'ts55', 'timeSlotRef2': 'ts56', 'timeStamp1': 135643, 'timeStamp2': 144210, 'text': 'Eblong patatan dabok malalte mateng han o milo yanik han'}
# AudioMetaData(sample_rate=44100, num_frames=108662, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MAIN', 144390, 144586]
# ['MARIU', 144681, 144870]
# ['HAN', 144906, 145008]
# ['MATAN', 145080, 145357]
# ['HONAMI', 145422, 145677]
# ['NGAMDADAGOKAI', 145727, 146854]
# [['MAIN', 144390, 144586], ['MARIU', 144681, 144870], ['HAN', 144906, 145008], ['MATAN', 145080, 145357], ['HONAMI', 145422, 145677], ['NGAMDADAGOKAI', 145727, 146854]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a38', 'timeSlotRef1': 'ts57', 'timeSlotRef2': 'ts58', 'timeStamp1': 144390, 'timeStamp2': 146854, 'text': 'Main mariu han matan honami ngamdadagokai'}
# AudioMetaData(sample_rate=44100, num_frames=248150, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 148340, 148645]
# ['NGAU', 148652, 149197]
# ['NERAURAU', 150801, 151339]
# ['SONGE', 151440, 151593]
# ['HAN', 151651, 151978]
# ['TAMATE', 152086, 152413]
# ['GAMONI', 152493, 152754]
# ['TIE', 152820, 153379]
# ['MAINE', 153451, 153967]
# [['DO', 148340, 148645], ['NGAU', 148652, 149197], ['NERAURAU', 150801, 151339], ['SONGE', 151440, 151593], ['HAN', 151651, 151978], ['TAMATE', 152086, 152413], ['GAMONI', 152493, 152754], ['TIE', 152820, 153379], ['MAINE', 153451, 153967]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a39', 'timeSlotRef1': 'ts59', 'timeSlotRef2': 'ts60', 'timeStamp1': 148340, 'timeStamp2': 153967, 'text': 'Do ngau neraurau songe han tamate gamoni tie maine'}
# AudioMetaData(sample_rate=44100, num_frames=263541, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 155663, 155982]
# ['NGAU', 156048, 156396]
# ['BAR', 156404, 156483]
# ['TA', 156527, 156643]
# ['NGABIP', 156671, 157050]
# ['TIDOP', 158800, 159148]
# ['TIE', 161036, 161639]
# [['DO', 155663, 155982], ['NGAU', 156048, 156396], ['BAR', 156404, 156483], ['TA', 156527, 156643], ['NGABIP', 156671, 157050], ['TIDOP', 158800, 159148], ['TIE', 161036, 161639]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a40', 'timeSlotRef1': 'ts61', 'timeSlotRef2': 'ts62', 'timeStamp1': 155663, 'timeStamp2': 161639, 'text': 'Do ngau bar ta ngabip tidop  tie'}
# AudioMetaData(sample_rate=44100, num_frames=100460, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 163649, 163998]
# ['BAR', 164086, 164268]
# ['MAINNANGAN', 164333, 164821]
# ['MAM', 164843, 164952]
# ['TIBUD', 165054, 165294]
# ['HAN', 165330, 165432]
# ['BAR', 165592, 165927]
# [['DO', 163649, 163998], ['BAR', 164086, 164268], ['MAINNANGAN', 164333, 164821], ['MAM', 164843, 164952], ['TIBUD', 165054, 165294], ['HAN', 165330, 165432], ['BAR', 165592, 165927]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a41', 'timeSlotRef1': 'ts63', 'timeSlotRef2': 'ts64', 'timeStamp1': 163649, 'timeStamp2': 165927, 'text': 'Do bar mainnangan mam Tibud han bar'}
# AudioMetaData(sample_rate=44100, num_frames=124936, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['OH', 169567, 170170]
# ['MAM', 170177, 171812]
# ['TIBUD', 171841, 172400]
# [['OH', 169567, 170170], ['MAM', 170177, 171812], ['TIBUD', 171841, 172400]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a42', 'timeSlotRef1': 'ts65', 'timeSlotRef2': 'ts66', 'timeStamp1': 169567, 'timeStamp2': 172400, 'text': 'Oh mam Tibud'}
# AudioMetaData(sample_rate=44100, num_frames=235803, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['TABUDAPE', 173396, 174769]
# ['MAM', 174929, 175350]
# ['HAN', 175401, 175924]
# ['GAMUK', 175990, 176382]
# ['TANONGPE', 176520, 178743]
# [['TABUDAPE', 173396, 174769], ['MAM', 174929, 175350], ['HAN', 175401, 175924], ['GAMUK', 175990, 176382], ['TANONGPE', 176520, 178743]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a43', 'timeSlotRef1': 'ts67', 'timeSlotRef2': 'ts68', 'timeStamp1': 173396, 'timeStamp2': 178743, 'text': 'Tabudape mam han gamuk tanongpe'}
# AudioMetaData(sample_rate=44100, num_frames=214546, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['TABUDAPE', 179000, 180234]
# ['MAM', 180365, 180779]
# ['HAN', 180852, 181019]
# ['GAMUK', 181055, 181875]
# ['TANONGPE', 182311, 183865]
# [['TABUDAPE', 179000, 180234], ['MAM', 180365, 180779], ['HAN', 180852, 181019], ['GAMUK', 181055, 181875], ['TANONGPE', 182311, 183865]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a44', 'timeSlotRef1': 'ts69', 'timeSlotRef2': 'ts70', 'timeStamp1': 179000, 'timeStamp2': 183865, 'text': 'Tabudape mam han gamuk tanongpe'}
# AudioMetaData(sample_rate=44100, num_frames=285812, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['TANGALEPA', 184125, 186312]
# ['BUBEDTE', 186414, 187249]
# ['BUBEDTE', 187358, 188187]
# ['TANAGEP', 188274, 188891]
# ['TANGALEPTATOR', 188957, 190606]
# [['TANGALEPA', 184125, 186312], ['BUBEDTE', 186414, 187249], ['BUBEDTE', 187358, 188187], ['TANAGEP', 188274, 188891], ['TANGALEPTATOR', 188957, 190606]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a45', 'timeSlotRef1': 'ts71', 'timeSlotRef2': 'ts72', 'timeStamp1': 184125, 'timeStamp2': 190606, 'text': 'Tangalepa bubedte bubedte tanagep tangaleptator'}
# AudioMetaData(sample_rate=44100, num_frames=214988, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['HUDUNGAN', 190776, 193609]
# ['TANONGE', 193747, 195651]
# [['HUDUNGAN', 190776, 193609], ['TANONGE', 193747, 195651]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a46', 'timeSlotRef1': 'ts73', 'timeSlotRef2': 'ts74', 'timeStamp1': 190776, 'timeStamp2': 195651, 'text': 'Hudungan tanonge'}
# AudioMetaData(sample_rate=44100, num_frames=210754, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['HUDUNGAN', 195975, 198938]
# ['TANONGE', 199439, 200754]
# [['HUDUNGAN', 195975, 198938], ['TANONGE', 199439, 200754]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a47', 'timeSlotRef1': 'ts75', 'timeSlotRef2': 'ts76', 'timeStamp1': 195975, 'timeStamp2': 200754, 'text': 'Hudungan tanonge'}
# AudioMetaData(sample_rate=44100, num_frames=287929, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['TANGALEPA', 201197, 202541]
# ['BUBEDTE', 202628, 203252]
# ['BUBEDTE', 203318, 204182]
# ['TANAGEP', 204240, 205082]
# ['TANGALEPTATOR', 205133, 207726]
# [['TANGALEPA', 201197, 202541], ['BUBEDTE', 202628, 203252], ['BUBEDTE', 203318, 204182], ['TANAGEP', 204240, 205082], ['TANGALEPTATOR', 205133, 207726]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a48', 'timeSlotRef1': 'ts77', 'timeSlotRef2': 'ts78', 'timeStamp1': 201197, 'timeStamp2': 207726, 'text': 'Tangalepa bubedte bubedte tanagep tangaleptator'}
# AudioMetaData(sample_rate=44100, num_frames=44938, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MAINAMI', 210078, 211096]
# [['MAINAMI', 210078, 211096]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a49', 'timeSlotRef1': 'ts79', 'timeSlotRef2': 'ts80', 'timeStamp1': 210078, 'timeStamp2': 211097, 'text': 'Mainami'}
# AudioMetaData(sample_rate=44100, num_frames=103723, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['BAR', 211413, 211748]
# ['MALAIN', 211799, 212112]
# ['KAI', 212229, 212411]
# ['HADOKATA', 212440, 212898]
# ['NGABINGE', 212906, 213765]
# [['BAR', 211413, 211748], ['MALAIN', 211799, 212112], ['KAI', 212229, 212411], ['HADOKATA', 212440, 212898], ['NGABINGE', 212906, 213765]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a50', 'timeSlotRef1': 'ts81', 'timeSlotRef2': 'ts82', 'timeStamp1': 211413, 'timeStamp2': 213765, 'text': 'Bar malain kai hadokata ngabinge'}
# AudioMetaData(sample_rate=44100, num_frames=260940, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['PAINIM', 217406, 217667]
# ['AINTA', 217740, 218147]
# ['DISOP', 218154, 218502]
# ['DIGAMUKABA', 218510, 219555]
# ['MANAGENGA', 219599, 220179]
# ['HADI', 220252, 220629]
# ['SABI', 221900, 222045]
# ['MATAN', 222074, 222321]
# ['TI', 222365, 222423]
# ['NGAMBIP', 222430, 223323]
# [['PAINIM', 217406, 217667], ['AINTA', 217740, 218147], ['DISOP', 218154, 218502], ['DIGAMUKABA', 218510, 219555], ['MANAGENGA', 219599, 220179], ['HADI', 220252, 220629], ['SABI', 221900, 222045], ['MATAN', 222074, 222321], ['TI', 222365, 222423], ['NGAMBIP', 222430, 223323]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a51', 'timeSlotRef1': 'ts83', 'timeSlotRef2': 'ts84', 'timeStamp1': 217406, 'timeStamp2': 223323, 'text': 'Painim ainta disop digamukaba managenga hadi sabi matan ti ngambip'}
# AudioMetaData(sample_rate=44100, num_frames=119732, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MAIN', 224507, 224944]
# ['HAN', 224973, 225155]
# ['LILIMAN', 225322, 225730]
# ['NGABINGE', 225875, 226130]
# ['MAIN', 226167, 226283]
# ['HUYANAMI', 226334, 227222]
# [['MAIN', 224507, 224944], ['HAN', 224973, 225155], ['LILIMAN', 225322, 225730], ['NGABINGE', 225875, 226130], ['MAIN', 226167, 226283], ['HUYANAMI', 226334, 227222]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a52', 'timeSlotRef1': 'ts85', 'timeSlotRef2': 'ts86', 'timeStamp1': 224507, 'timeStamp2': 227222, 'text': 'Main han liliman ngabinge main huyanami'}
# AudioMetaData(sample_rate=44100, num_frames=49348, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['ESEIDI', 229292, 230411]
# [['ESEIDI', 229292, 230411]]
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a53', 'timeSlotRef1': 'ts87', 'timeSlotRef2': 'ts88', 'timeStamp1': 229292, 'timeStamp2': 230411, 'text': 'Eseidi'}
# {'Cathy Samun Wiliang_a1': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 4730, 'timeStamp2': 7480, 'text': 'Yangau Cathy Samun ai', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['YANGAU', 4730, 5407], ['CATHY', 6294, 6687], ['SAMUN', 6745, 7116], ['AI', 7276, 7480]]}, 'Cathy Samun Wiliang_a2': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8860, 'timeStamp2': 10780, 'text': 'Ngahau mam yangan Daidai ai', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['NGAHAU', 8860, 9216], ['MAM', 9296, 9427], ['YANGAN', 9507, 9653], ['DAIDAI', 9682, 10067], ['AI', 10075, 10780]]}, 'Cathy Samun Wiliang_a3': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11821, 'timeStamp2': 14853, 'text': 'Ngau tamat yangan Wiliang Yasung ai', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['NGAU', 11821, 12337], ['TAMAT', 12439, 12672], ['YANGAN', 12759, 13043], ['WILIANG', 13144, 13493], ['YASUNG', 14031, 14584], ['AI', 14591, 14853]]}, 'Cathy Samun Wiliang_a4': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15733, 'timeStamp2': 19160, 'text': 'Ngahau nen mam Matugar tamatpainim', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['NGAHAU', 15733, 16394], ['NEN', 16553, 16720], ['MAM', 17802, 17911], ['MATUGAR', 17955, 18231], ['TAMATPAINIM', 18281, 19160]]}, 'Cathy Samun Wiliang_a5': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 20618, 'timeStamp2': 22709, 'text': 'Ngau Matugar tamat ngangalenge', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['NGAU', 20618, 21026], ['MATUGAR', 21092, 21463], ['TAMAT', 21514, 21776], ['NGANGALENGE', 21849, 22709]]}, 'Cathy Samun Wiliang_a6': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 24013, 'timeStamp2': 25977, 'text': 'Hamam aipain aim tol', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['HAMAM', 24013, 24755], ['AIPAIN', 24893, 25184], ['AIM', 25279, 25359], ['TOL', 25482, 25977]]}, 'Cathy Samun Wiliang_a7': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 27757, 'timeStamp2': 34253, 'text': 'Muganen mainangan Gumos ai Salome ai do aim tahaik  Yasung ai', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['MUGANEN', 27757, 28266], ['MAINANGAN', 28302, 29029], ['GUMOS', 29668, 30322], ['AI', 30366, 30416], ['SALOME', 30518, 31158], ['AI', 31267, 31296], ['DO', 31347, 31361], ['AIM', 31492, 31601], ['TAHAIK', 31775, 32088], ['YASUNG', 33403, 33839], ['AI', 33991, 34253]]}, 'Cathy Samun Wiliang_a9': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a9', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 34721, 'timeStamp2': 37607, 'text': 'Tibun han yayaman ngamnagenge tamat', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['TIBUN', 34721, 35230], ['HAN', 35484, 35593], ['YAYAMAN', 35848, 36386], ['NGAMNAGENGE', 36458, 37076], ['TAMAT', 37113, 37607]]}, 'Cathy Samun Wiliang_a10': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a10', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 38705, 'timeStamp2': 40537, 'text': 'Do ngau sulelo ngauwe', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['DO', 38705, 39221], ['NGAU', 39265, 39432], ['SULELO', 39476, 40413], ['NGAUWE', 40421, 40537]]}, 'Cathy Samun Wiliang_a11': {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a11', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 40926, 'timeStamp2': 43717, 'text': 'Ngahau sule tomante ti tiale', 'tier_new': 'Cathy Samun Wiliang_words', 'words': [['NGAHAU', 40926, 41747], ['SULE', 41827, 42140], ['TOMANTE', 42191, 42685], ['TI', 42758, 42874], ['TIALE', 42954, 43717]]}, 'Cathy Samun Wiliang_a12': {'tiername': 'Cathy Samun ...
# AudioMetaData(sample_rate=44100, num_frames=192453, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 2877, 3545]
# ['NERAURAU', 3618, 4300]
# ['MAINANGAN', 4307, 5353]
# ['NGAHAU', 5520, 6079]
# ['NENLO', 6108, 6326]
# ['NGAGAMUKABA', 6355, 6914]
# [['NGAU', 2877, 3545], ['NERAURAU', 3618, 4300], ['MAINANGAN', 4307, 5353], ['NGAHAU', 5520, 6079], ['NENLO', 6108, 6326], ['NGAGAMUKABA', 6355, 6914]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 2877, 'timeStamp2': 7241, 'text': 'Ngau neraurau mainangan ngahau nenlo ngagamukaba '}
# AudioMetaData(sample_rate=44100, num_frames=104958, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 8181, 8545]
# ['NEN', 8574, 8625]
# ['MAINANGAN', 8661, 9469]
# ['MATUGAR', 9477, 9891]
# ['PAIN', 10001, 10561]
# [['NGAHAU', 8181, 8545], ['NEN', 8574, 8625], ['MAINANGAN', 8661, 9469], ['MATUGAR', 9477, 9891], ['PAIN', 10001, 10561]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8181, 'timeStamp2': 10561, 'text': 'Ngahau nen mainangan Matugar pain'}
# AudioMetaData(sample_rate=44100, num_frames=121848, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MADONGE', 11412, 12408]
# ['YAWE', 12459, 12655]
# ['KUDAG', 12793, 13026]
# ['TAMAT', 13142, 13382]
# ['NGALENGE', 13506, 14175]
# [['MADONGE', 11412, 12408], ['YAWE', 12459, 12655], ['KUDAG', 12793, 13026], ['TAMAT', 13142, 13382], ['NGALENGE', 13506, 14175]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11412, 'timeStamp2': 14175, 'text': 'Madonge yawe Kudag tamat ngalenge'}
# AudioMetaData(sample_rate=44100, num_frames=108486, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['IDA', 15006, 15297]
# ['DIMADONGE', 15326, 15668]
# ['DINAGAYAMAME', 15712, 17211]
# [['IDA', 15006, 15297], ['DIMADONGE', 15326, 15668], ['DINAGAYAMAME', 15712, 17211]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15006, 'timeStamp2': 17466, 'text': 'Ida dimadonge dinagayamame '}
# AudioMetaData(sample_rate=44100, num_frames=106237, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DIYAMATAMAME', 17604, 18914]
# ['YAUWE', 18994, 19176]
# ['NGAM', 19198, 19387]
# ['HUYAHUYAE', 19394, 20013]
# [['DIYAMATAMAME', 17604, 18914], ['YAUWE', 18994, 19176], ['NGAM', 19198, 19387], ['HUYAHUYAE', 19394, 20013]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 17604, 'timeStamp2': 20013, 'text': 'Diyamatamame yauwe ngam huyahuyae'}
# AudioMetaData(sample_rate=44100, num_frames=145530, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 20206, 20657]
# ['NGAUWE', 20722, 20998]
# ['PAIN', 21136, 21304]
# ['DABOKADO', 21333, 22256]
# ['TAMAT', 22481, 22699]
# ['NGANGALENGE', 22815, 23506]
# [['NGAU', 20206, 20657], ['NGAUWE', 20722, 20998], ['PAIN', 21136, 21304], ['DABOKADO', 21333, 22256], ['TAMAT', 22481, 22699], ['NGANGALENGE', 22815, 23506]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 20206, 'timeStamp2': 23506, 'text': 'Ngau ngauwe pain dabokado tamat ngangalenge'}
# AudioMetaData(sample_rate=44100, num_frames=117173, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAHAU', 24760, 25146]
# ['TAMAT', 25240, 25495]
# ['MAINANGAN', 25561, 26158]
# ['ALI', 26391, 26449]
# ['DO', 26500, 26609]
# ['SURUMARAN', 26624, 27191]
# [['NGAHAU', 24760, 25146], ['TAMAT', 25240, 25495], ['MAINANGAN', 25561, 26158], ['ALI', 26391, 26449], ['DO', 26500, 26609], ['SURUMARAN', 26624, 27191]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 24760, 'timeStamp2': 27417, 'text': 'Ngahau tamat mainangan Ali do Surumaran '}
# AudioMetaData(sample_rate=44100, num_frames=179796, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAMADONGE', 28168, 28960]
# ['NGAU', 28982, 29294]
# ['TAMAT', 29360, 29571]
# ['AB', 29687, 29789]
# ['YABINGE', 29839, 30428]
# ['ABI', 30494, 30690]
# ['NGAMBINGE', 30697, 31504]
# ['TIE', 31511, 32245]
# [['NGAMADONGE', 28168, 28960], ['NGAU', 28982, 29294], ['TAMAT', 29360, 29571], ['AB', 29687, 29789], ['YABINGE', 29839, 30428], ['ABI', 30494, 30690], ['NGAMBINGE', 30697, 31504], ['TIE', 31511, 32245]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a8', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 28168, 'timeStamp2': 32245, 'text': 'Ngamadonge ngau tamat ab yabinge abi ngambinge tie'}
# AudioMetaData(sample_rate=44100, num_frames=139356, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAMADONDO', 32486, 33387]
# ['NGAU', 33438, 33612]
# ['AIM', 33801, 34026]
# ['AIPAINIM', 34186, 34665]
# ['NGANAGEDINE', 34709, 35646]
# [['NGAMADONDO', 32486, 33387], ['NGAU', 33438, 33612], ['AIM', 33801, 34026], ['AIPAINIM', 34186, 34665], ['NGANAGEDINE', 34709, 35646]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a9', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 32486, 'timeStamp2': 35646, 'text': 'Ngamadondo ngau aim aipainim nganagedine'}
# AudioMetaData(sample_rate=44100, num_frames=109235, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAM', 36392, 36559]
# ['YAMATAIE', 36639, 37453]
# ['NGAMADONGE', 37518, 37983]
# ['YAU', 38477, 38869]
# [['NGAM', 36392, 36559], ['YAMATAIE', 36639, 37453], ['NGAMADONGE', 37518, 37983], ['YAU', 38477, 38869]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a10', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 36392, 'timeStamp2': 38869, 'text': 'Ngam yamataie ngamadonge yau'}
# AudioMetaData(sample_rate=44100, num_frames=140679, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MALAL', 39088, 39466]
# ['MAIN', 39517, 39655]
# ['NGAMMENINGE', 39677, 40018]
# ['HAUN', 40251, 40512]
# ['MALAL', 40570, 40846]
# ['TURAN', 40919, 41123]
# ['NGAMAWE', 41188, 41530]
# ['NGAMMADONGE', 41588, 42278]
# [['MALAL', 39088, 39466], ['MAIN', 39517, 39655], ['NGAMMENINGE', 39677, 40018], ['HAUN', 40251, 40512], ['MALAL', 40570, 40846], ['TURAN', 40919, 41123], ['NGAMAWE', 41188, 41530], ['NGAMMADONGE', 41588, 42278]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a11', 'timeSlotRef1': 'ts21', 'timeSlotRef2': 'ts22', 'timeStamp1': 39088, 'timeStamp2': 42278, 'text': 'Malal main ngammeninge haun malal turan ngamawe ngammadonge'}
# AudioMetaData(sample_rate=44100, num_frames=34398, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['ABEN', 42308, 42665]
# ['HAUN', 42694, 43088]
# [['ABEN', 42308, 42665], ['HAUN', 42694, 43088]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a12', 'timeSlotRef1': 'ts23', 'timeSlotRef2': 'ts24', 'timeStamp1': 42308, 'timeStamp2': 43088, 'text': 'Aben haun'}
# AudioMetaData(sample_rate=44100, num_frames=42204, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAM', 43668, 44033]
# ['MADONGE', 44274, 44625]
# [['NGAM', 43668, 44033], ['MADONGE', 44274, 44625]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a13', 'timeSlotRef1': 'ts25', 'timeSlotRef2': 'ts26', 'timeStamp1': 43668, 'timeStamp2': 44625, 'text': 'Ngam madonge'}
# AudioMetaData(sample_rate=44100, num_frames=44100, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['YAUWE', 44755, 45755]
# [['YAUWE', 44755, 45755]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a14', 'timeSlotRef1': 'ts27', 'timeSlotRef2': 'ts28', 'timeStamp1': 44755, 'timeStamp2': 45755, 'text': 'Yauwe'}
# AudioMetaData(sample_rate=44100, num_frames=97637, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['AB', 46495, 46925]
# ['YABINGE', 47063, 47347]
# ['MALALHAUN', 47369, 48221]
# ['MAINTE', 48330, 48709]
# [['AB', 46495, 46925], ['YABINGE', 47063, 47347], ['MALALHAUN', 47369, 48221], ['MAINTE', 48330, 48709]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a15', 'timeSlotRef1': 'ts29', 'timeSlotRef2': 'ts30', 'timeStamp1': 46495, 'timeStamp2': 48709, 'text': 'Ab yabinge malalhaun mainte'}
# AudioMetaData(sample_rate=44100, num_frames=344421, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['AB', 48709, 48919]
# ['YABINGE', 49079, 49478]
# ['NGAMADONGE', 49507, 49972]
# ['ABINGAMBINGE', 50066, 50480]
# ['NGAMAM', 50516, 50930]
# ['AIPAINIM', 51039, 51634]
# ['NGAMYAMATAIDO', 51670, 52766]
# ['NGAMYAMATAIDO', 52941, 55024]
# ['YAU', 55089, 55242]
# ['HUYAN', 55285, 55503]
# ['HUYANE', 55575, 56519]
# [['AB', 48709, 48919], ['YABINGE', 49079, 49478], ['NGAMADONGE', 49507, 49972], ['ABINGAMBINGE', 50066, 50480], ['NGAMAM', 50516, 50930], ['AIPAINIM', 51039, 51634], ['NGAMYAMATAIDO', 51670, 52766], ['NGAMYAMATAIDO', 52941, 55024], ['YAU', 55089, 55242], ['HUYAN', 55285, 55503], ['HUYANE', 55575, 56519]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a16', 'timeSlotRef1': 'ts31', 'timeSlotRef2': 'ts32', 'timeStamp1': 48709, 'timeStamp2': 56519, 'text': 'Ab yabinge ngamadonge abingambinge ngamam aipainim ngamyamataido ngamyamataido yau huyan huyane'}
# AudioMetaData(sample_rate=44100, num_frames=189674, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DIYAUWE', 57046, 57889]
# ['SULELO', 57911, 58354]
# ['DIYADINE', 58535, 58964]
# ['AIPAINIM', 59015, 59465]
# ['NGAU', 59494, 59661]
# ['AIPAINIM', 59669, 59996]
# ['HUDUNGAN', 60025, 60359]
# ['SULE', 60366, 60693]
# ['DIYAUALE', 60700, 61180]
# [['DIYAUWE', 57046, 57889], ['SULELO', 57911, 58354], ['DIYADINE', 58535, 58964], ['AIPAINIM', 59015, 59465], ['NGAU', 59494, 59661], ['AIPAINIM', 59669, 59996], ['HUDUNGAN', 60025, 60359], ['SULE', 60366, 60693], ['DIYAUALE', 60700, 61180]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a17', 'timeSlotRef1': 'ts33', 'timeSlotRef2': 'ts34', 'timeStamp1': 57046, 'timeStamp2': 61347, 'text': 'Diyauwe sulelo diyadine aipainim ngau aipainim hudungan sule diyauale  '}
# AudioMetaData(sample_rate=44100, num_frames=260896, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DIYAUWE', 61757, 62432]
# ['DISULEDO', 62468, 63093]
# ['NGAM', 63100, 63339]
# ['NGAMADONGE', 63376, 63739]
# ['MALALTE', 63760, 64145]
# ['ABI', 64385, 64610]
# ['NGAMBINGDO', 64617, 65103]
# ['BOM', 65154, 65350]
# ['HURAT', 66120, 66512]
# ['NGAMNAGENDO', 66642, 67484]
# [['DIYAUWE', 61757, 62432], ['DISULEDO', 62468, 63093], ['NGAM', 63100, 63339], ['NGAMADONGE', 63376, 63739], ['MALALTE', 63760, 64145], ['ABI', 64385, 64610], ['NGAMBINGDO', 64617, 65103], ['BOM', 65154, 65350], ['HURAT', 66120, 66512], ['NGAMNAGENDO', 66642, 67484]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a18', 'timeSlotRef1': 'ts35', 'timeSlotRef2': 'ts36', 'timeStamp1': 61757, 'timeStamp2': 67673, 'text': 'Diyauwe disuledo ngam ngamadonge malalte abi ngambingdo bom hurat ngamnagendo '}
# AudioMetaData(sample_rate=44100, num_frames=205726, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['BOM', 67903, 68513]
# ['NGAMNGALE', 68557, 68905]
# ['PALUM', 68957, 69218]
# ['ABATE', 69233, 69385]
# ['HIENDOPE', 69451, 69916]
# ['NGAMPIDAP', 70068, 70599]
# ['WASINGWAI', 70657, 71129]
# ['DARUKWAI', 71137, 71652]
# ['NGAMTORAGO', 71660, 72219]
# [['BOM', 67903, 68513], ['NGAMNGALE', 68557, 68905], ['PALUM', 68957, 69218], ['ABATE', 69233, 69385], ['HIENDOPE', 69451, 69916], ['NGAMPIDAP', 70068, 70599], ['WASINGWAI', 70657, 71129], ['DARUKWAI', 71137, 71652], ['NGAMTORAGO', 71660, 72219]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a19', 'timeSlotRef1': 'ts37', 'timeSlotRef2': 'ts38', 'timeStamp1': 67903, 'timeStamp2': 72568, 'text': 'Bom ngamngale palum abate hiendope ngampidap wasingwai darukwai ngamtorago '}
# AudioMetaData(sample_rate=44100, num_frames=132962, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['WASING', 73036, 73661]
# ['DARUK', 73668, 73893]
# ['NGAM', 73944, 74206]
# ['ABATE', 74307, 74721]
# ['NGAM', 74729, 75019]
# ['NAGEHIANDOPE', 75056, 76051]
# [['WASING', 73036, 73661], ['DARUK', 73668, 73893], ['NGAM', 73944, 74206], ['ABATE', 74307, 74721], ['NGAM', 74729, 75019], ['NAGEHIANDOPE', 75056, 76051]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a20', 'timeSlotRef1': 'ts39', 'timeSlotRef2': 'ts40', 'timeStamp1': 73036, 'timeStamp2': 76051, 'text': 'Wasing daruk ngam abate ngam nagehiandope'}
# AudioMetaData(sample_rate=44100, num_frames=280035, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAMNEIMA', 77062, 78028]
# ['GARIB', 78232, 78442]
# ['NGAMBAL', 78457, 78922]
# ['TAMAT', 79002, 79227]
# ['DISAPID', 79336, 79554]
# ['NGAM', 79728, 79968]
# ['PANDIN', 80128, 80484]
# ['DININDOP', 80535, 80920]
# ['DIADINAGO', 80985, 81646]
# ['NGAU', 81654, 81821]
# ['AIPAINIM', 81901, 82228]
# ['NGAMYAMATAIGO', 82235, 83412]
# [['NGAMNEIMA', 77062, 78028], ['GARIB', 78232, 78442], ['NGAMBAL', 78457, 78922], ['TAMAT', 79002, 79227], ['DISAPID', 79336, 79554], ['NGAM', 79728, 79968], ['PANDIN', 80128, 80484], ['DININDOP', 80535, 80920], ['DIADINAGO', 80985, 81646], ['NGAU', 81654, 81821], ['AIPAINIM', 81901, 82228], ['NGAMYAMATAIGO', 82235, 83412]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a21', 'timeSlotRef1': 'ts41', 'timeSlotRef2': 'ts42', 'timeStamp1': 77062, 'timeStamp2': 83412, 'text': 'Ngamneima garib ngambal tamat disapid ngam pandin dinindop diadinago ngau aipainim ngamyamataigo'}
# AudioMetaData(sample_rate=44100, num_frames=111352, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 83602, 84046]
# ['TAMAT', 84119, 84381]
# ['MAIN', 84497, 84620]
# ['TI', 84715, 84875]
# ['HURAT', 84890, 85021]
# ['NAGENGGOKAI', 85166, 86127]
# [['NGAU', 83602, 84046], ['TAMAT', 84119, 84381], ['MAIN', 84497, 84620], ['TI', 84715, 84875], ['HURAT', 84890, 85021], ['NAGENGGOKAI', 85166, 86127]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a22', 'timeSlotRef1': 'ts43', 'timeSlotRef2': 'ts44', 'timeStamp1': 83602, 'timeStamp2': 86127, 'text': 'Ngau tamat main ti hurat nagenggokai'}
# AudioMetaData(sample_rate=44100, num_frames=58036, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MALALTE', 86305, 86938]
# ['MADONGGO', 86959, 87621]
# [['MALALTE', 86305, 86938], ['MADONGGO', 86959, 87621]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a23', 'timeSlotRef1': 'ts45', 'timeSlotRef2': 'ts46', 'timeStamp1': 86305, 'timeStamp2': 87621, 'text': 'Malalte madonggo'}
# AudioMetaData(sample_rate=44100, num_frames=279021, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MARIU', 87893, 88590]
# ['KAKAU', 88808, 89259]
# ['PAIDINAGO', 89346, 90181]
# ['MAIN', 90864, 91155]
# ['NGANGALEMA', 91169, 92360]
# ['NGADADDOPE', 92506, 92956]
# ['MATAN', 92971, 93334]
# ['NGANGALENGO', 93363, 94220]
# [['MARIU', 87893, 88590], ['KAKAU', 88808, 89259], ['PAIDINAGO', 89346, 90181], ['MAIN', 90864, 91155], ['NGANGALEMA', 91169, 92360], ['NGADADDOPE', 92506, 92956], ['MATAN', 92971, 93334], ['NGANGALENGO', 93363, 94220]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a24', 'timeSlotRef1': 'ts47', 'timeSlotRef2': 'ts48', 'timeStamp1': 87893, 'timeStamp2': 94220, 'text': 'Mariu kakau paidinago main ngangalema ngadaddope matan ngangalengo'}
# AudioMetaData(sample_rate=44100, num_frames=234877, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MATAN', 94738, 94956]
# ['NGANGALEMA', 94963, 95319]
# ['NGAHAU', 95334, 95922]
# ['AIPAINIM', 96482, 96852]
# ['ADI', 96918, 97078]
# ['SULUNGADI', 97114, 97623]
# ['DADAGO', 97637, 98291]
# ['DINAGENDOPE', 98364, 99054]
# ['SULE', 99061, 99214]
# ['DIYAWE', 99272, 100064]
# [['MATAN', 94738, 94956], ['NGANGALEMA', 94963, 95319], ['NGAHAU', 95334, 95922], ['AIPAINIM', 96482, 96852], ['ADI', 96918, 97078], ['SULUNGADI', 97114, 97623], ['DADAGO', 97637, 98291], ['DINAGENDOPE', 98364, 99054], ['SULE', 99061, 99214], ['DIYAWE', 99272, 100064]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a25', 'timeSlotRef1': 'ts49', 'timeSlotRef2': 'ts50', 'timeStamp1': 94738, 'timeStamp2': 100064, 'text': 'Matan ngangalema ngahau aipainim adi sulungadi dadago dinagendope sule diyawe'}
# AudioMetaData(sample_rate=44100, num_frames=329339, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['DO', 100803, 101094]
# ['NGAMADONGE', 101144, 101624]
# ['YAUWE', 101813, 101980]
# ['GAMONI', 102023, 102394]
# ['MAINANGAN', 102445, 102917]
# ['NGAMAM', 102924, 103920]
# ['AB', 103927, 104108]
# ['GAM', 104181, 104428]
# ['AYANE', 105125, 105445]
# ['WAGAMANENAGO', 105474, 106353]
# ['NGAMAM', 106527, 106789]
# ['ABATE', 106905, 107290]
# ['SUL', 107298, 107545]
# ['TATI', 107617, 108082]
# [['DO', 100803, 101094], ['NGAMADONGE', 101144, 101624], ['YAUWE', 101813, 101980], ['GAMONI', 102023, 102394], ['MAINANGAN', 102445, 102917], ['NGAMAM', 102924, 103920], ['AB', 103927, 104108], ['GAM', 104181, 104428], ['AYANE', 105125, 105445], ['WAGAMANENAGO', 105474, 106353], ['NGAMAM', 106527, 106789], ['ABATE', 106905, 107290], ['SUL', 107298, 107545], ['TATI', 107617, 108082]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a26', 'timeSlotRef1': 'ts51', 'timeSlotRef2': 'ts52', 'timeStamp1': 100803, 'timeStamp2': 108271, 'text': 'Do ngamadonge yauwe gamoni mainangan ngamam ab gam ayane wagamanenago ngamam abate sul tati '}
# AudioMetaData(sample_rate=44100, num_frames=76690, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['GAMONI', 108771, 109142]
# ['NGAMMADONGGO', 109178, 109695]
# ['MAIN', 109753, 110510]
# [['GAMONI', 108771, 109142], ['NGAMMADONGGO', 109178, 109695], ['MAIN', 109753, 110510]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a27', 'timeSlotRef1': 'ts53', 'timeSlotRef2': 'ts54', 'timeStamp1': 108771, 'timeStamp2': 110510, 'text': 'Gamoni ngammadonggo main'}
# AudioMetaData(sample_rate=44100, num_frames=294147, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MANAGE', 110765, 111804]
# ['NGAMAM', 112109, 112393]
# ['MADOK', 112422, 112640]
# ['GAMONI', 112836, 113279]
# ['MAIN', 113308, 113497]
# ['I', 113533, 113541]
# ['LOMAM', 113555, 113962]
# ['GERENGGO', 114006, 114209]
# ['AB', 114296, 114376]
# ['HONA', 114427, 114609]
# ['NGAMINDOP', 114630, 115154]
# ['SUL', 115219, 115495]
# ['NGAMAM', 116040, 116454]
# ['ABATE', 116534, 116723]
# ['PALUMBAI', 116788, 117435]
# [['MANAGE', 110765, 111804], ['NGAMAM', 112109, 112393], ['MADOK', 112422, 112640], ['GAMONI', 112836, 113279], ['MAIN', 113308, 113497], ['I', 113533, 113541], ['LOMAM', 113555, 113962], ['GERENGGO', 114006, 114209], ['AB', 114296, 114376], ['HONA', 114427, 114609], ['NGAMINDOP', 114630, 115154], ['SUL', 115219, 115495], ['NGAMAM', 116040, 116454], ['ABATE', 116534, 116723], ['PALUMBAI', 116788, 117435]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a28', 'timeSlotRef1': 'ts55', 'timeSlotRef2': 'ts56', 'timeStamp1': 110765, 'timeStamp2': 117435, 'text': 'Manage ngamam madok gamoni main i lomam gerenggo ab hona ngamindop sul ngamam abate palumbai'}
# AudioMetaData(sample_rate=44100, num_frames=105708, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MAIN', 118199, 118620]
# ['WAI', 118649, 118787]
# ['I', 118882, 118947]
# ['LOMAM', 118983, 119129]
# ['GIRENDO', 119180, 119521]
# ['NGAMMADONGGO', 119528, 120596]
# [['MAIN', 118199, 118620], ['WAI', 118649, 118787], ['I', 118882, 118947], ['LOMAM', 118983, 119129], ['GIRENDO', 119180, 119521], ['NGAMMADONGGO', 119528, 120596]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a29', 'timeSlotRef1': 'ts57', 'timeSlotRef2': 'ts58', 'timeStamp1': 118199, 'timeStamp2': 120596, 'text': 'Main wai i lomam girendo ngammadonggo'}
# AudioMetaData(sample_rate=44100, num_frames=110426, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['MAINAMI', 122705, 123571]
# ['NGAHAU', 123578, 123833]
# ['GAMUK', 123899, 124066]
# ['TAKURAN', 124183, 124510]
# ['MAINAMI', 124561, 125209]
# [['MAINAMI', 122705, 123571], ['NGAHAU', 123578, 123833], ['GAMUK', 123899, 124066], ['TAKURAN', 124183, 124510], ['MAINAMI', 124561, 125209]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a30', 'timeSlotRef1': 'ts59', 'timeSlotRef2': 'ts60', 'timeStamp1': 122705, 'timeStamp2': 125209, 'text': 'Mainami ngahau gamuk takuran mainami'}
# AudioMetaData(sample_rate=44100, num_frames=95520, num_channels=2, bits_per_sample=16, encoding=PCM_S)
# ['NGAU', 127931, 128244]
# ['NERAURAU', 128251, 128571]
# ['TIYALE', 128665, 130097]
# [['NGAU', 127931, 128244], ['NERAURAU', 128251, 128571], ['TIYALE', 128665, 130097]]
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a31', 'timeSlotRef1': 'ts61', 'timeSlotRef2': 'ts62', 'timeStamp1': 127931, 'timeStamp2': 130097, 'text': 'Ngau neraurau tiyale'}
# {'Kadagoi Lovinea Rapalau_a1': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 2877, 'timeStamp2': 7241, 'text': 'Ngau neraurau mainangan ngahau nenlo ngagamukaba ', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAU', 2877, 3545], ['NERAURAU', 3618, 4300], ['MAINANGAN', 4307, 5353], ['NGAHAU', 5520, 6079], ['NENLO', 6108, 6326], ['NGAGAMUKABA', 6355, 6914]]}, 'Kadagoi Lovinea Rapalau_a2': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8181, 'timeStamp2': 10561, 'text': 'Ngahau nen mainangan Matugar pain', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAHAU', 8181, 8545], ['NEN', 8574, 8625], ['MAINANGAN', 8661, 9469], ['MATUGAR', 9477, 9891], ['PAIN', 10001, 10561]]}, 'Kadagoi Lovinea Rapalau_a3': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11412, 'timeStamp2': 14175, 'text': 'Madonge yawe Kudag tamat ngalenge', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['MADONGE', 11412, 12408], ['YAWE', 12459, 12655], ['KUDAG', 12793, 13026], ['TAMAT', 13142, 13382], ['NGALENGE', 13506, 14175]]}, 'Kadagoi Lovinea Rapalau_a4': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15006, 'timeStamp2': 17466, 'text': 'Ida dimadonge dinagayamame ', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['IDA', 15006, 15297], ['DIMADONGE', 15326, 15668], ['DINAGAYAMAME', 15712, 17211]]}, 'Kadagoi Lovinea Rapalau_a5': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 17604, 'timeStamp2': 20013, 'text': 'Diyamatamame yauwe ngam huyahuyae', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['DIYAMATAMAME', 17604, 18914], ['YAUWE', 18994, 19176], ['NGAM', 19198, 19387], ['HUYAHUYAE', 19394, 20013]]}, 'Kadagoi Lovinea Rapalau_a6': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 20206, 'timeStamp2': 23506, 'text': 'Ngau ngauwe pain dabokado tamat ngangalenge', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAU', 20206, 20657], ['NGAUWE', 20722, 20998], ['PAIN', 21136, 21304], ['DABOKADO', 21333, 22256], ['TAMAT', 22481, 22699], ['NGANGALENGE', 22815, 23506]]}, 'Kadagoi Lovinea Rapalau_a7': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 24760, 'timeStamp2': 27417, 'text': 'Ngahau tamat mainangan Ali do Surumaran ', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAHAU', 24760, 25146], ['TAMAT', 25240, 25495], ['MAINANGAN', 25561, 26158], ['ALI', 26391, 26449], ['DO', 26500, 26609], ['SURUMARAN', 26624, 27191]]}, 'Kadagoi Lovinea Rapalau_a8': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a8', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 28168, 'timeStamp2': 32245, 'text': 'Ngamadonge ngau tamat ab yabinge abi ngambinge tie', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAMADONGE', 28168, 28960], ['NGAU', 28982, 29294], ['TAMAT', 29360, 29571], ['AB', 29687, 29789], ['YABINGE', 29839, 30428], ['ABI', 30494, 30690], ['NGAMBINGE', 30697, 31504], ['TIE', 31511, 32245]]}, 'Kadagoi Lovinea Rapalau_a9': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a9', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 32486, 'timeStamp2': 35646, 'text': 'Ngamadondo ngau aim aipainim nganagedine', 'tier_new': 'Kadagoi Lovinea Rapalau_words', 'words': [['NGAMADONDO', 32486, 33387], ['NGAU', 33438, 33612], ['AIM', 33801, 34026], ['AIPAINIM', 34186, 34665], ['NGANAGEDINE', 34709, 35646]]}, 'Kadagoi Lovinea Rapalau_a10': {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a10', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 36392, 'timeStamp2': 38869, 'text': 'Ngam yamataie ngamadonge  ...

# %%
def display_segment(i):
    ratio = waveform.size(1) / trellis.size(0)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / 44100:.3f} - {x1 / 44100:.3f} sec")
    segment = waveform[:, x0:x1]

    return IPython.display.Audio(segment.numpy(), rate=44100)

display_segment(1)
# Out:
# TAMAT (0.78): 0.618 - 0.851 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(SPEECH_FILE, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
"C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_a1.wav"
"C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy Samun Wiliang_a1.wav"

"C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_a53.wav"
