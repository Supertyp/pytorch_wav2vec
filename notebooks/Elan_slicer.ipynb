# %% [markdown]
# ## ELAN slicer
# - this notebook uses ELAN .eaf files to slice the audio into small junks which can be handled fast by CPU base automatic alignment in audiotorch
# - the wav file gets sliced into small snippets
# - a json file with the small transcript for each wav snippet is also created

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import os
import sys
import json
from pydub import AudioSegment
import xml.etree.ElementTree as ET

# !pip install pympi-ling
# !{sys.executable} -m pip install pydub
# Out:
# Requirement already satisfied: pympi-ling in c:\users\barth\anaconda3\lib\site-packages (1.70.2)
# Requirement already satisfied: pydub in c:\users\barth\anaconda3\lib\site-packages (0.25.1)

# %% [markdown]
# # Automatically set up required folders
# - input  # all source ELAN and wav files go in here for processing. The files stay unchanged
# - media_snippets # will hold all the wav snippets for processing
# - output # the final result ELAN files will be in here

# %%
folder_path = 'C:\\Users\\barth\\gits\\pytorch_wav2vec\\test_data\\'

def create_folder(base_folder, folderName):
    new_folder = os.path.join(base_folder, folderName)

    if not os.path.exists(new_folder):
        os.makedirs(new_folder)
        print(f"Folder '" + folderName + f"' created inside '{base_folder}'.")
    else:
        print("The '" + folderName + f"' folder already exists inside '{base_folder}'.")

# create the basic folder structure withing the folder_path
create_folder(folder_path, "input")
create_folder(folder_path, "media_snippets")
create_folder(folder_path, "output")


# set the path variables
inputPath = folder_path + "input\\"
mediaPath = folder_path + "media_snippets\\"
outputPath = folder_path + "output\\"
# Out:
# The 'input' folder already exists inside 'C:\Users\barth\gits\pytorch_wav2vec\test_data\'.
# The 'media_snippets' folder already exists inside 'C:\Users\barth\gits\pytorch_wav2vec\test_data\'.
# The 'output' folder already exists inside 'C:\Users\barth\gits\pytorch_wav2vec\test_data\'.

# %% [markdown]
# ## create json file with objects for each annotation

# %%
# Function to parse TIME_ORDER elements
def parse_time_order(root):
    time_slots_dict = {}
    for time_slot_elem in root.iter('TIME_SLOT'):
        
        time_slot_id = time_slot_elem.attrib.get('TIME_SLOT_ID')
        time_value = time_slot_elem.attrib.get('TIME_VALUE')

        if time_slot_id is not None and time_value is not None:
            time_slots_dict[time_slot_id] = time_value
            
    return time_slots_dict


# Function to parse annotation elements
def parse_annotations(root, time_slots_dict):
    
    data = {}

    # 'TIER' is the parent tag of 'ANNOTATION' elements
    for tier_elem in root.iter('TIER'):

        for annotation_elem in tier_elem.iter('ANNOTATION'):
            
            for alignable_annotation_elem in annotation_elem.iter('ALIGNABLE_ANNOTATION'):
       
                anno = {"tiername": tier_elem.attrib["TIER_ID"], 
                        "annoID": alignable_annotation_elem.attrib['ANNOTATION_ID'], 
                        "timeSlotRef1": alignable_annotation_elem.attrib['TIME_SLOT_REF1'], 
                        "timeSlotRef2": alignable_annotation_elem.attrib['TIME_SLOT_REF2'], 
                        "timeStamp1": int(time_slots_dict.get(alignable_annotation_elem.attrib['TIME_SLOT_REF1'])), 
                        "timeStamp2": int(time_slots_dict.get(alignable_annotation_elem.attrib['TIME_SLOT_REF2'])), 
                        "text": alignable_annotation_elem.find('ANNOTATION_VALUE').text,
                        "words": [],
                        "phonemes": []
                       }
                
                data[anno["tiername"] + "_" + anno["annoID"]] = anno 
    return data


def parse_xml(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # get all timeslots into a dictionary
    time_slots_dict = parse_time_order(root)

    # get all annotations
    data = parse_annotations(root, time_slots_dict)

    json_file_path = os.path.splitext(eaf_file_path)[0] + '.json'

    
    folder_path = os.path.dirname(xml_file_path)
    file_name = os.path.basename(xml_file_path)
    json_file_path = mediaPath + file_name[:-4] + ".json"
    
    with open(json_file_path, 'w') as json_file:
        json.dump(data, json_file, indent=2)



# Process each .eaf file in the folder
for filename in os.listdir(folder_path + "/input/"):
    
    if filename.endswith('.eaf'):
        eaf_file_path = os.path.join(folder_path + "/input/", filename)
        print(eaf_file_path)
        parse_xml(eaf_file_path)

print ("+++ DONE +++")
# Out:
# C:\Users\barth\gits\pytorch_wav2vec\test_data\/input/Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412.eaf
# C:\Users\barth\gits\pytorch_wav2vec\test_data\/input/Kadagoi_Lovinea_Rapalau_Life_Story_20130422.eaf
# +++ DONE +++

# %%
def slice_wav_file(input_wav_path, output_wav_path, start_time, end_time):
    # Load the entire audio file
    audio = AudioSegment.from_wav(input_wav_path)

    # Slice the audio based on start_time and end_time
    sliced_audio = audio[start_time:end_time]

    # Export the sliced audio to a new file
    sliced_audio.export(output_wav_path, format="wav")

def read_json_file(filename):
    try:
        with open(filename, 'r') as json_file:
            data = json.load(json_file)
            return data
    except Exception as e:
        print(f"Error reading JSON file: {e}")
        return None

for filename in os.listdir(mediaPath):
    
    counter  = 0
    if filename.endswith('.json'):
        
        newFolder = folder_path + "media_snippets\\"
        
        create_folder(newFolder, filename[:-5])
        
        json_data = read_json_file(mediaPath + filename)
        
        input_wav_path = inputPath + filename[:-5] + ".wav"
        #print (audio_file)
        for k, v in json_data.items():
            print (v)
            

            snippetname = k
            snippetname = snippetname.replace(":", "_").replace(" ", "_")
            output_wav_path = newFolder + filename[:-5] + "\\" + snippetname + ".wav"
            start = v["timeStamp1"]
            end = v["timeStamp2"]
            print (output_wav_path, start, end)
        
            slice_wav_file(input_wav_path, output_wav_path, start, end)

print ("+++ DONE +++")
# Out:
# Folder 'Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412' created inside 'C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\'.
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 4730, 'timeStamp2': 7480, 'text': 'Yangau Cathy Samun ai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a1.wav 4730 7480
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8860, 'timeStamp2': 10780, 'text': 'Ngahau mam yangan Daidai ai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a2.wav 8860 10780
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11821, 'timeStamp2': 14853, 'text': 'Ngau tamat yangan Wiliang Yasung ai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a3.wav 11821 14853
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15733, 'timeStamp2': 19160, 'text': 'Ngahau nen mam Matugar tamatpainim', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a4.wav 15733 19160
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 20618, 'timeStamp2': 22709, 'text': 'Ngau Matugar tamat ngangalenge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a5.wav 20618 22709
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 24013, 'timeStamp2': 25977, 'text': 'Hamam aipain aim tol', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a6.wav 24013 25977
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 27757, 'timeStamp2': 34253, 'text': 'Muganen mainangan Gumos ai Salome ai do aim tahaik  Yasung ai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a7.wav 27757 34253
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a9', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 34721, 'timeStamp2': 37607, 'text': 'Tibun han yayaman ngamnagenge tamat', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a9.wav 34721 37607
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a10', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 38705, 'timeStamp2': 40537, 'text': 'Do ngau sulelo ngauwe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a10.wav 38705 40537
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a11', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 40926, 'timeStamp2': 43717, 'text': 'Ngahau sule tomante ti tiale', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a11.wav 40926 43717
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a12', 'timeSlotRef1': 'ts21', 'timeSlotRef2': 'ts22', 'timeStamp1': 44815, 'timeStamp2': 45871, 'text': 'Matengalo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a12.wav 44815 45871
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a13', 'timeSlotRef1': 'ts23', 'timeSlotRef2': 'ts24', 'timeStamp1': 46642, 'timeStamp2': 50625, 'text': 'Mateng funauwe ngam sule han tomante ti tie', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a13.wav 46642 50625
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a14', 'timeSlotRef1': 'ts25', 'timeSlotRef2': 'ts26', 'timeStamp1': 52201, 'timeStamp2': 56240, 'text': 'Do nen mam dida ngammadonge yauwe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a14.wav 52201 56240
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a15', 'timeSlotRef1': 'ts27', 'timeSlotRef2': 'ts28', 'timeStamp1': 57160, 'timeStamp2': 59871, 'text': 'Nal ngau pain daboke tamat ngangalenge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a15.wav 57160 59871
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a16', 'timeSlotRef1': 'ts29', 'timeSlotRef2': 'ts30', 'timeStamp1': 60079, 'timeStamp2': 63712, 'text': 'Aipainim nganagedine malal mainte ngamadonge Matugar malal ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a16.wav 60079 63712
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a17', 'timeSlotRef1': 'ts31', 'timeSlotRef2': 'ts32', 'timeStamp1': 65418, 'timeStamp2': 69422, 'text': 'Do  ngahau neraurau ngapasimbai main mariu han', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a17.wav 65418 69422
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a18', 'timeSlotRef1': 'ts33', 'timeSlotRef2': 'ts34', 'timeStamp1': 70869, 'timeStamp2': 73140, 'text': 'Ngahau tamat ida ngamadong  ngau tamat', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a18.wav 70869 73140
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a19', 'timeSlotRef1': 'ts35', 'timeSlotRef2': 'ts36', 'timeStamp1': 74450, 'timeStamp2': 80220, 'text': 'Sulelo yakai ilo grek ti ida tidase malalte madonge ngaleuwe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a19.wav 74450 80220
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a21', 'timeSlotRef1': 'ts37', 'timeSlotRef2': 'ts38', 'timeStamp1': 81473, 'timeStamp2': 85328, 'text': 'Ngamadondo ngahamam aipainim yamataie ngale matan ti', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a21.wav 81473 85328
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a23', 'timeSlotRef1': 'ts39', 'timeSlotRef2': 'ts40', 'timeStamp1': 86828, 'timeStamp2': 94656, 'text': 'Do manig ilomam girenge tan ngambip mariu ngampaip matan ngamngalep ngahamam aipainim ngamyamataiba', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a23.wav 86828 94656
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a25', 'timeSlotRef1': 'ts41', 'timeSlotRef2': 'ts42', 'timeStamp1': 96153, 'timeStamp2': 100556, 'text': 'Do mariu ngampainge bras numau tahaik ilonlo aginon nagenge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a25.wav 96153 100556
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a26', 'timeSlotRef1': 'ts43', 'timeSlotRef2': 'ts44', 'timeStamp1': 100694, 'timeStamp2': 107289, 'text': 'Yap disinge ngamam mariu didado mainhona  ngahau aipainim adi sule ngadadagokai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a26.wav 100694 107289
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a28', 'timeSlotRef1': 'ts45', 'timeSlotRef2': 'ts46', 'timeStamp1': 107437, 'timeStamp2': 111344, 'text': 'Hadi sulungak nagekanen han ngadadagokai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a28.wav 107437 111344
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a30', 'timeSlotRef1': 'ts47', 'timeSlotRef2': 'ts48', 'timeStamp1': 111907, 'timeStamp2': 115824, 'text': 'Ngahamam madok kabakab adi milo yanikanen main matan  main hona', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a30.wav 111907 115824
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a31', 'timeSlotRef1': 'ts49', 'timeSlotRef2': 'ts50', 'timeStamp1': 116579, 'timeStamp2': 122575, 'text': 'Patatan malalte nagekanen mariu han matan honami  ngambi ngammalenggokai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a31.wav 116579 122575
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a33', 'timeSlotRef1': 'ts51', 'timeSlotRef2': 'ts52', 'timeStamp1': 124050, 'timeStamp2': 130867, 'text': 'Do gamoni ngau abate wap ngahau ab mainangan mariu han matan honami milo ngamaninggo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a33.wav 124050 130867
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a35', 'timeSlotRef1': 'ts53', 'timeSlotRef2': 'ts54', 'timeStamp1': 131085, 'timeStamp2': 133745, 'text': 'Mariu han matan honami milo milo hudungan', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a35.wav 131085 133745
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a36', 'timeSlotRef1': 'ts55', 'timeSlotRef2': 'ts56', 'timeStamp1': 135643, 'timeStamp2': 144210, 'text': 'Eblong patatan dabok malalte mateng han o milo yanik han', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a36.wav 135643 144210
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a38', 'timeSlotRef1': 'ts57', 'timeSlotRef2': 'ts58', 'timeStamp1': 144390, 'timeStamp2': 146854, 'text': 'Main mariu han matan honami ngamdadagokai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a38.wav 144390 146854
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a39', 'timeSlotRef1': 'ts59', 'timeSlotRef2': 'ts60', 'timeStamp1': 148340, 'timeStamp2': 153967, 'text': 'Do ngau neraurau songe han tamate gamoni tie maine', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a39.wav 148340 153967
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a40', 'timeSlotRef1': 'ts61', 'timeSlotRef2': 'ts62', 'timeStamp1': 155663, 'timeStamp2': 161639, 'text': 'Do ngau bar ta ngabip tidop  tie', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a40.wav 155663 161639
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a41', 'timeSlotRef1': 'ts63', 'timeSlotRef2': 'ts64', 'timeStamp1': 163649, 'timeStamp2': 165927, 'text': 'Do bar mainnangan mam Tibud han bar', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a41.wav 163649 165927
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a42', 'timeSlotRef1': 'ts65', 'timeSlotRef2': 'ts66', 'timeStamp1': 169567, 'timeStamp2': 172400, 'text': 'Oh mam Tibud', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a42.wav 169567 172400
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a43', 'timeSlotRef1': 'ts67', 'timeSlotRef2': 'ts68', 'timeStamp1': 173396, 'timeStamp2': 178743, 'text': 'Tabudape mam han gamuk tanongpe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a43.wav 173396 178743
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a44', 'timeSlotRef1': 'ts69', 'timeSlotRef2': 'ts70', 'timeStamp1': 179000, 'timeStamp2': 183865, 'text': 'Tabudape mam han gamuk tanongpe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a44.wav 179000 183865
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a45', 'timeSlotRef1': 'ts71', 'timeSlotRef2': 'ts72', 'timeStamp1': 184125, 'timeStamp2': 190606, 'text': 'Tangalepa bubedte bubedte tanagep tangaleptator', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a45.wav 184125 190606
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a46', 'timeSlotRef1': 'ts73', 'timeSlotRef2': 'ts74', 'timeStamp1': 190776, 'timeStamp2': 195651, 'text': 'Hudungan tanonge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a46.wav 190776 195651
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a47', 'timeSlotRef1': 'ts75', 'timeSlotRef2': 'ts76', 'timeStamp1': 195975, 'timeStamp2': 200754, 'text': 'Hudungan tanonge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a47.wav 195975 200754
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a48', 'timeSlotRef1': 'ts77', 'timeSlotRef2': 'ts78', 'timeStamp1': 201197, 'timeStamp2': 207726, 'text': 'Tangalepa bubedte bubedte tanagep tangaleptator', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a48.wav 201197 207726
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a49', 'timeSlotRef1': 'ts79', 'timeSlotRef2': 'ts80', 'timeStamp1': 210078, 'timeStamp2': 211097, 'text': 'Mainami', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a49.wav 210078 211097
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a50', 'timeSlotRef1': 'ts81', 'timeSlotRef2': 'ts82', 'timeStamp1': 211413, 'timeStamp2': 213765, 'text': 'Bar malain kai hadokata ngabinge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a50.wav 211413 213765
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a51', 'timeSlotRef1': 'ts83', 'timeSlotRef2': 'ts84', 'timeStamp1': 217406, 'timeStamp2': 223323, 'text': 'Painim ainta disop digamukaba managenga hadi sabi matan ti ngambip', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a51.wav 217406 223323
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a52', 'timeSlotRef1': 'ts85', 'timeSlotRef2': 'ts86', 'timeStamp1': 224507, 'timeStamp2': 227222, 'text': 'Main han liliman ngabinge main huyanami', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a52.wav 224507 227222
# {'tiername': 'Cathy Samun Wiliang', 'annoID': 'a53', 'timeSlotRef1': 'ts87', 'timeSlotRef2': 'ts88', 'timeStamp1': 229292, 'timeStamp2': 230411, 'text': 'Eseidi', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Cathy_Samun_Wiliang_Buai_and_Tabudape_Chorus_20130412\Cathy_Samun_Wiliang_a53.wav 229292 230411
# Folder 'Kadagoi_Lovinea_Rapalau_Life_Story_20130422' created inside 'C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\'.
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a1', 'timeSlotRef1': 'ts1', 'timeSlotRef2': 'ts2', 'timeStamp1': 2877, 'timeStamp2': 7241, 'text': 'Ngau neraurau mainangan ngahau nenlo ngagamukaba ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a1.wav 2877 7241
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a2', 'timeSlotRef1': 'ts3', 'timeSlotRef2': 'ts4', 'timeStamp1': 8181, 'timeStamp2': 10561, 'text': 'Ngahau nen mainangan Matugar pain', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a2.wav 8181 10561
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a3', 'timeSlotRef1': 'ts5', 'timeSlotRef2': 'ts6', 'timeStamp1': 11412, 'timeStamp2': 14175, 'text': 'Madonge yawe Kudag tamat ngalenge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a3.wav 11412 14175
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a4', 'timeSlotRef1': 'ts7', 'timeSlotRef2': 'ts8', 'timeStamp1': 15006, 'timeStamp2': 17466, 'text': 'Ida dimadonge dinagayamame ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a4.wav 15006 17466
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a5', 'timeSlotRef1': 'ts9', 'timeSlotRef2': 'ts10', 'timeStamp1': 17604, 'timeStamp2': 20013, 'text': 'Diyamatamame yauwe ngam huyahuyae', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a5.wav 17604 20013
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a6', 'timeSlotRef1': 'ts11', 'timeSlotRef2': 'ts12', 'timeStamp1': 20206, 'timeStamp2': 23506, 'text': 'Ngau ngauwe pain dabokado tamat ngangalenge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a6.wav 20206 23506
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a7', 'timeSlotRef1': 'ts13', 'timeSlotRef2': 'ts14', 'timeStamp1': 24760, 'timeStamp2': 27417, 'text': 'Ngahau tamat mainangan Ali do Surumaran ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a7.wav 24760 27417
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a8', 'timeSlotRef1': 'ts15', 'timeSlotRef2': 'ts16', 'timeStamp1': 28168, 'timeStamp2': 32245, 'text': 'Ngamadonge ngau tamat ab yabinge abi ngambinge tie', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a8.wav 28168 32245
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a9', 'timeSlotRef1': 'ts17', 'timeSlotRef2': 'ts18', 'timeStamp1': 32486, 'timeStamp2': 35646, 'text': 'Ngamadondo ngau aim aipainim nganagedine', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a9.wav 32486 35646
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a10', 'timeSlotRef1': 'ts19', 'timeSlotRef2': 'ts20', 'timeStamp1': 36392, 'timeStamp2': 38869, 'text': 'Ngam yamataie ngamadonge yau', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a10.wav 36392 38869
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a11', 'timeSlotRef1': 'ts21', 'timeSlotRef2': 'ts22', 'timeStamp1': 39088, 'timeStamp2': 42278, 'text': 'Malal main ngammeninge haun malal turan ngamawe ngammadonge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a11.wav 39088 42278
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a12', 'timeSlotRef1': 'ts23', 'timeSlotRef2': 'ts24', 'timeStamp1': 42308, 'timeStamp2': 43088, 'text': 'Aben haun', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a12.wav 42308 43088
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a13', 'timeSlotRef1': 'ts25', 'timeSlotRef2': 'ts26', 'timeStamp1': 43668, 'timeStamp2': 44625, 'text': 'Ngam madonge', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a13.wav 43668 44625
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a14', 'timeSlotRef1': 'ts27', 'timeSlotRef2': 'ts28', 'timeStamp1': 44755, 'timeStamp2': 45755, 'text': 'Yauwe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a14.wav 44755 45755
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a15', 'timeSlotRef1': 'ts29', 'timeSlotRef2': 'ts30', 'timeStamp1': 46495, 'timeStamp2': 48709, 'text': 'Ab yabinge malalhaun mainte', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a15.wav 46495 48709
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a16', 'timeSlotRef1': 'ts31', 'timeSlotRef2': 'ts32', 'timeStamp1': 48709, 'timeStamp2': 56519, 'text': 'Ab yabinge ngamadonge abingambinge ngamam aipainim ngamyamataido ngamyamataido yau huyan huyane', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a16.wav 48709 56519
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a17', 'timeSlotRef1': 'ts33', 'timeSlotRef2': 'ts34', 'timeStamp1': 57046, 'timeStamp2': 61347, 'text': 'Diyauwe sulelo diyadine aipainim ngau aipainim hudungan sule diyauale  ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a17.wav 57046 61347
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a18', 'timeSlotRef1': 'ts35', 'timeSlotRef2': 'ts36', 'timeStamp1': 61757, 'timeStamp2': 67673, 'text': 'Diyauwe disuledo ngam ngamadonge malalte abi ngambingdo bom hurat ngamnagendo ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a18.wav 61757 67673
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a19', 'timeSlotRef1': 'ts37', 'timeSlotRef2': 'ts38', 'timeStamp1': 67903, 'timeStamp2': 72568, 'text': 'Bom ngamngale palum abate hiendope ngampidap wasingwai darukwai ngamtorago ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a19.wav 67903 72568
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a20', 'timeSlotRef1': 'ts39', 'timeSlotRef2': 'ts40', 'timeStamp1': 73036, 'timeStamp2': 76051, 'text': 'Wasing daruk ngam abate ngam nagehiandope', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a20.wav 73036 76051
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a21', 'timeSlotRef1': 'ts41', 'timeSlotRef2': 'ts42', 'timeStamp1': 77062, 'timeStamp2': 83412, 'text': 'Ngamneima garib ngambal tamat disapid ngam pandin dinindop diadinago ngau aipainim ngamyamataigo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a21.wav 77062 83412
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a22', 'timeSlotRef1': 'ts43', 'timeSlotRef2': 'ts44', 'timeStamp1': 83602, 'timeStamp2': 86127, 'text': 'Ngau tamat main ti hurat nagenggokai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a22.wav 83602 86127
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a23', 'timeSlotRef1': 'ts45', 'timeSlotRef2': 'ts46', 'timeStamp1': 86305, 'timeStamp2': 87621, 'text': 'Malalte madonggo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a23.wav 86305 87621
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a24', 'timeSlotRef1': 'ts47', 'timeSlotRef2': 'ts48', 'timeStamp1': 87893, 'timeStamp2': 94220, 'text': 'Mariu kakau paidinago main ngangalema ngadaddope matan ngangalengo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a24.wav 87893 94220
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a25', 'timeSlotRef1': 'ts49', 'timeSlotRef2': 'ts50', 'timeStamp1': 94738, 'timeStamp2': 100064, 'text': 'Matan ngangalema ngahau aipainim adi sulungadi dadago dinagendope sule diyawe', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a25.wav 94738 100064
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a26', 'timeSlotRef1': 'ts51', 'timeSlotRef2': 'ts52', 'timeStamp1': 100803, 'timeStamp2': 108271, 'text': 'Do ngamadonge yauwe gamoni mainangan ngamam ab gam ayane wagamanenago ngamam abate sul tati ', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a26.wav 100803 108271
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a27', 'timeSlotRef1': 'ts53', 'timeSlotRef2': 'ts54', 'timeStamp1': 108771, 'timeStamp2': 110510, 'text': 'Gamoni ngammadonggo main', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a27.wav 108771 110510
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a28', 'timeSlotRef1': 'ts55', 'timeSlotRef2': 'ts56', 'timeStamp1': 110765, 'timeStamp2': 117435, 'text': 'Manage ngamam madok gamoni main i lomam gerenggo ab hona ngamindop sul ngamam abate palumbai', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a28.wav 110765 117435
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a29', 'timeSlotRef1': 'ts57', 'timeSlotRef2': 'ts58', 'timeStamp1': 118199, 'timeStamp2': 120596, 'text': 'Main wai i lomam girendo ngammadonggo', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a29.wav 118199 120596
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a30', 'timeSlotRef1': 'ts59', 'timeSlotRef2': 'ts60', 'timeStamp1': 122705, 'timeStamp2': 125209, 'text': 'Mainami ngahau gamuk takuran mainami', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a30.wav 122705 125209
# {'tiername': 'Kadagoi Lovinea Rapalau', 'annoID': 'a31', 'timeSlotRef1': 'ts61', 'timeSlotRef2': 'ts62', 'timeStamp1': 127931, 'timeStamp2': 130097, 'text': 'Ngau neraurau tiyale', 'words': [], 'phonemes': []}
# C:\Users\barth\gits\pytorch_wav2vec\test_data\media_snippets\Kadagoi_Lovinea_Rapalau_Life_Story_20130422\Kadagoi_Lovinea_Rapalau_a31.wav 127931 130097
# +++ DONE +++
